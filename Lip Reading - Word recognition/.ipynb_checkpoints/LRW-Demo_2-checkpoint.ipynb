# %%
import cv2
import mediapipe as mp
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
carpeta_principal = 'lipread_mp4_demo/'
word_path = []
ttv_path = []

for entrada in os.listdir(carpeta_principal):
    ruta_absoluta = os.path.join(carpeta_principal, entrada)
    # Verifica si la entrada es una carpeta
    if os.path.isdir(ruta_absoluta):
        # Ruta de la carpeta que contiene las imágenes
        carpeta_1 = carpeta_principal + entrada
        # Itera sobre todos los archivos en la carpeta
        for subcarpeta in os.listdir(carpeta_1):
            # Itera sobre todas las carpetas test, train y val
            carpeta_2 = carpeta_1+'/'+subcarpeta
            # Obtener la lista de elementos (archivos y carpetas) en la carpeta
            elementos = os.listdir(carpeta_2)
            # Contar el número de elementos en la lista
            num_elementos = len(elementos)
            ttv_path.append(int(num_elementos/2))

        word_path.append(ttv_path)
        ttv_path = []

word_path
# Out:
# [[50, 1000, 50],
#  [50, 853, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 954, 50],
#  [50, 834, 50],
#  [50, 1000, 50]]

# %%
carpeta_principal = 'img_mouth_lipread_demo/'

ttv_cont = 0
ttv_value = []
for files in word_path:
    for file_lenght in files:
        for i in range(file_lenght):
            ttv_value.append(ttv_cont)
        ttv_cont = ttv_cont + 1
    ttv_cont = 0

# %%
len(ttv_value)
# Out:
# 10641

# %%
carpeta_principal = 'img_mouth_lipread_demo/'

test = []
train = []
value = []
clip = []
i = 0

for entrada in os.listdir(carpeta_principal):
    ruta_absoluta = os.path.join(carpeta_principal, entrada)
    image= cv2.imread(ruta_absoluta)
    clip.append(image)
    
    if(len(clip) == 10):
        if (ttv_value[i] == 0):
            test.append(clip)
        else:
            if (ttv_value[i] == 1):
                train.append(clip)
            else:
                if (ttv_value[i] == 2):
                    value.append(clip)
        i = i + 1
        clip = []

# %%
print(len(test), len(train), len(value))
# Out:
# 500 9641 500

# %%
plt.imshow(cv2.cvtColor(test[0][9], cv2.COLOR_BGR2RGB))

# %%
test_np = np.array(test)
train_np = np.array(train)
value_np = np.array(value)
print("test_np shape: ", test_np.shape)
print("train_np shape: ", train_np.shape)
print("value_np shape: ", value_np.shape)
# Out:
# test_np shape:  (500, 10, 60, 80, 3)
# train_np shape:  (9641, 10, 60, 80, 3)
# value_np shape:  (500, 10, 60, 80, 3)

# %%
y_test = []
y_train = []
y_value = []
word_count = 0
for files in word_path:
    for i in range(files[0]):
        y_test.append(word_count)
    for i in range(files[1]):
        y_train.append(word_count)
    for i in range(files[2]):
        y_value.append(word_count)
    word_count = word_count + 1

# %%
print(len(y_test), len(y_train), len(y_value))
# Out:
# 500 9641 500

# %%
y_test_np = np.array(y_test)
y_train_np = np.array(y_train)
y_value_np = np.array(y_value)
print("test_np shape: ", y_test_np.shape)
print("train_np shape: ", y_train_np.shape)
print("value_np shape: ", y_value_np.shape)
# Out:
# test_np shape:  (500,)
# train_np shape:  (9641,)
# value_np shape:  (500,)

# %%
class CFG:
    epochs = 10
    batch_size = 32
    classes = ["ATTACK", "BLACK", "FINAL", "IMPACT", "LATER", "MEDIA", "OFFICE", "PRESS", "SPEND", "WEEKS"]

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_np, y_train_np)).shuffle(CFG.batch_size * 4).batch(CFG.batch_size).cache().prefetch(tf.data.AUTOTUNE)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 60, 80, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
valid_ds = tf.data.Dataset.from_tensor_slices((test_np, y_test_np)).batch(CFG.batch_size).cache().prefetch(tf.data.AUTOTUNE)

# %%
valid_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10, 60, 80, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
for X, y in train_ds.take(1):
    print(X.shape, y.shape)
# Out:
# (32, 10, 60, 80, 3) (32,)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.Input(shape=(10, 60, 80, 3)),
    tf.keras.layers.Conv3D(32, kernel_size=3, padding="same", activation="relu"),
    tf.keras.layers.MaxPooling3D(),
    tf.keras.layers.Conv3D(64, kernel_size=3, padding="same", activation="relu"),
    tf.keras.layers.MaxPooling3D(),
    tf.keras.layers.Conv3D(128, kernel_size=3, padding="same", activation="relu"),
    tf.keras.layers.MaxPooling3D(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.GlobalAveragePooling3D(),
    tf.keras.layers.Dense(len(CFG.classes), activation="softmax")
])
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
    optimizer=tf.keras.optimizers.Adam(0.001),
    metrics=[
        "accuracy"
    ]
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                      │ (None, 10, 60, 80, 32)      │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d (MaxPooling3D)         │ (None, 5, 30, 40, 32)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_1 (Conv3D)                    │ (None, 5, 30, 40, 64)       │          55,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_1 (MaxPooling3D)       │ (None, 2, 15, 20, 64)       │               0 │
# ...

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "model_PreMouth.keras", 
    monitor="val_accuracy",
    mode="max",
    save_best_only=True
)
history = model.fit(
    train_np, y_train_np, 
    epochs=30, 
    validation_data=(value_np, y_value_np), 
    callbacks=[checkpoint]
)
model.load_weights("model.keras")
# Out:
# Epoch 1/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 167s 552ms/step - accuracy: 0.4054 - loss: 1.6981 - val_accuracy: 0.4420 - val_loss: 1.5764
# Epoch 2/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 168s 555ms/step - accuracy: 0.4803 - loss: 1.5136 - val_accuracy: 0.5300 - val_loss: 1.4307
# Epoch 3/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 166s 550ms/step - accuracy: 0.5400 - loss: 1.3645 - val_accuracy: 0.5820 - val_loss: 1.3341
# Epoch 4/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 168s 556ms/step - accuracy: 0.5989 - loss: 1.2349 - val_accuracy: 0.6020 - val_loss: 1.2356
# Epoch 5/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 165s 545ms/step - accuracy: 0.6106 - loss: 1.1975 - val_accuracy: 0.6320 - val_loss: 1.1618
# Epoch 6/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 164s 544ms/step - accuracy: 0.6372 - loss: 1.1206 - val_accuracy: 0.5700 - val_loss: 1.2694
# Epoch 7/30
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 164s 543ms/step - accuracy: 0.6526 - loss: 1.0548 - val_accuracy: 0.6340 - val_loss: 1.1216
# Epoch 8/30
# ...

# %%
for metrics in [("loss", "val_loss"), ("accuracy", "val_accuracy")]:
    pd.DataFrame(history.history, columns=metrics).plot()
    plt.show()

# %%
val_loss, val_acc = model.evaluate(value_np, y_value_np)
print(f"Validation Loss:{val_loss} Validation Accuracy:{val_acc}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - accuracy: 0.0659 - loss: 2.3189
# Validation Loss:2.3061153888702393 Validation Accuracy:0.10000000149011612

# %%
net = tf.keras.applications.EfficientNetB0(include_top = False)
net.trainable = False

efficient_net_model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(255.0),
    tf.keras.layers.TimeDistributed(net),
    tf.keras.layers.Dense(len(CFG.classes)),
    tf.keras.layers.GlobalAveragePooling3D()
])

efficient_net_model.compile(optimizer = 'adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
history = efficient_net_model.fit(
    train_np, y_train_np,
    epochs = 10,
    validation_data=(value_np, y_value_np),
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'),
        tf.keras.callbacks.ModelCheckpoint(
            "efficient_net_model.weights.h5", 
            monitor="val_accuracy",
            mode="max",
            save_best_only=True,
            save_weights_only=True
        )
    ]
)
# Out:
# Epoch 1/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 142s 471ms/step - accuracy: 0.1096 - loss: 1146.7203 - val_accuracy: 0.0840 - val_loss: 82.0527
# Epoch 2/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 139s 461ms/step - accuracy: 0.1054 - loss: 106.1972 - val_accuracy: 0.0880 - val_loss: 68.1181
# Epoch 3/10
# 145/302 ━━━━━━━━━━━━━━━━━━━━ 1:09 444ms/step - accuracy: 0.1178 - loss: 91.5102
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 history = efficient_net_model.fit(
#       2     train_np, y_train_np,
#       3     epochs = 10,
#       4     validation_data=(value_np, y_value_np),
#       5     callbacks = [
#       6         tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'),
#       7         tf.keras.callbacks.ModelCheckpoint(
#       8             "efficient_net_model.weights.h5",
#       9             monitor="val_accuracy",
# ...

# %%
for metrics in [("loss", "val_loss"), ("accuracy", "val_accuracy")]:
    pd.DataFrame(history.history, columns=metrics).plot()
    plt.show()

# %%
val_loss, val_acc = efficient_net_model.evaluate(valid_ds)
print(f"Validation Loss:{val_loss} Validation Accuracy:{val_acc}")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Reshape

# Definir el modelo
model = Sequential()
model.add(Reshape((10, 80*60*3), input_shape=(10, 80, 60, 3)))  # Asume que cada imagen tiene un tamaño de 80x60 y 3 canales (RGB)
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))  # Asume que num_classes es el número de palabras distintas que estás tratando de predecir

# Compilar el modelo
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# Entrenar el modelo
model.fit(train_np, y_train_np, validation_data=(value_np, y_value_np), epochs=10)

# Evaluar el modelo en el conjunto de prueba
loss, accuracy = model.evaluate(test_np, y_test_np)
print("Test Accuracy: ", accuracy)
# Out:
# Epoch 1/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 53s 154ms/step - accuracy: 0.1021 - loss: 2.3100 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 2/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.0935 - loss: 2.3017 - val_accuracy: 0.1000 - val_loss: 2.3034
# Epoch 3/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.1054 - loss: 2.3010 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 4/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.1024 - loss: 2.3004 - val_accuracy: 0.1000 - val_loss: 2.3042
# Epoch 5/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 45s 150ms/step - accuracy: 0.1049 - loss: 2.3003 - val_accuracy: 0.1000 - val_loss: 2.3045
# Epoch 6/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 45s 149ms/step - accuracy: 0.1075 - loss: 2.3008 - val_accuracy: 0.1000 - val_loss: 2.3046
# Epoch 7/10
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - accuracy: 0.0961 - loss: 2.3017 - val_accuracy: 0.1000 - val_loss: 2.3047
# Epoch 8/10
# ...
