# %% [markdown]
# ### Llibreries

# %%
import cv2
import mediapipe as mp
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## Lip Reading - Word Recognition entrenat amb 'Conv3D layer'

# %% [markdown]
# ### Llibreries

# %%
carpeta_principal = 'lipread_mp4_demo/'
word_path = []
ttv_path = []

for entrada in os.listdir(carpeta_principal):
    ruta_absoluta = os.path.join(carpeta_principal, entrada)
    # Verifica si la entrada es una carpeta
    if os.path.isdir(ruta_absoluta):
        # Ruta de la carpeta que contiene las imágenes
        carpeta_1 = carpeta_principal + entrada
        # Itera sobre todos los archivos en la carpeta
        for subcarpeta in os.listdir(carpeta_1):
            # Itera sobre todas las carpetas test, train y val
            carpeta_2 = carpeta_1+'/'+subcarpeta
            # Obtener la lista de elementos (archivos y carpetas) en la carpeta
            elementos = os.listdir(carpeta_2)
            # Contar el número de elementos en la lista
            num_elementos = len(elementos)
            ttv_path.append(int(num_elementos/2))

        word_path.append(ttv_path)
        ttv_path = []

word_path
# Out:
# [[50, 1000, 50],
#  [50, 853, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 1000, 50],
#  [50, 954, 50],
#  [50, 834, 50],
#  [50, 1000, 50]]

# %%
carpeta_principal = 'img_mouth_lipread_demo/'

ttv_cont = 0
ttv_value = []
for files in word_path:
    for file_lenght in files:
        for i in range(file_lenght):
            ttv_value.append(ttv_cont)
        ttv_cont = ttv_cont + 1
    ttv_cont = 0

# %%
len(ttv_value)
# Out:
# 10641

# %%
carpeta_principal = 'img_mouth_lipread_resize_demo/'

test = []
train = []
value = []
clip = []
i = 0

for entrada in os.listdir(carpeta_principal):
    ruta_absoluta = os.path.join(carpeta_principal, entrada)
    image= cv2.imread(ruta_absoluta)
    clip.append(image)
    
    if(len(clip) == 10):
        if (ttv_value[i] == 0):
            test.append(clip)
        else:
            if (ttv_value[i] == 1):
                train.append(clip)
            else:
                if (ttv_value[i] == 2):
                    value.append(clip)
        i = i + 1
        clip = []

# %%
print(len(test), len(train), len(value))
# Out:
# 500 9641 500

# %%
plt.imshow(cv2.cvtColor(test[0][9], cv2.COLOR_BGR2RGB))

# %%
test_np = np.array(test)
train_np = np.array(train)
value_np = np.array(value)
print("test_np shape: ", test_np.shape)
print("train_np shape: ", train_np.shape)
print("value_np shape: ", value_np.shape)
# Out:
# test_np shape:  (500, 10, 50, 100, 3)
# train_np shape:  (9641, 10, 50, 100, 3)
# value_np shape:  (500, 10, 50, 100, 3)

# %%
y_test = []
y_train = []
y_value = []
word_count = 0
for files in word_path:
    for i in range(files[0]):
        y_test.append(word_count)
    for i in range(files[1]):
        y_train.append(word_count)
    for i in range(files[2]):
        y_value.append(word_count)
    word_count = word_count + 1

# %%
print(len(y_test), len(y_train), len(y_value))
# Out:
# 500 9641 500

# %%
y_test_np = np.array(y_test)
y_train_np = np.array(y_train)
y_value_np = np.array(y_value)
print("test_np shape: ", y_test_np.shape)
print("train_np shape: ", y_train_np.shape)
print("value_np shape: ", y_value_np.shape)
# Out:
# test_np shape:  (500,)
# train_np shape:  (9641,)
# value_np shape:  (500,)

# %%
from sklearn.model_selection import train_test_split

train_features, val_features, train_targets, val_targets = train_test_split(train_np, y_train_np, test_size=0.2, random_state=42)

# %%
class CFG:
    epochs = 10
    batch_size = 32
    classes = ["ATTACK", "BLACK", "FINAL", "IMPACT", "LATER", "MEDIA", "OFFICE", "PRESS", "SPEND", "WEEKS"]

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_features, train_targets)).shuffle(CFG.batch_size * 4).batch(CFG.batch_size).cache().prefetch(tf.data.AUTOTUNE)

# %%
valid_ds = tf.data.Dataset.from_tensor_slices((val_features, val_targets)).batch(CFG.batch_size).cache().prefetch(tf.data.AUTOTUNE)

# %%
for X, y in train_ds.take(1):
    print(X.shape, y.shape)
# Out:
# (32, 10, 50, 100, 3) (32,)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.Input(shape=(10, 50, 100, 3)),
    tf.keras.layers.Conv3D(32, kernel_size=3, padding="same", activation="relu"),
    tf.keras.layers.MaxPooling3D(),
    tf.keras.layers.Conv3D(64, kernel_size=3, padding="same", activation="relu"),
    tf.keras.layers.MaxPooling3D(),
    tf.keras.layers.Conv3D(128, kernel_size=3, padding="same", activation="relu"),
    tf.keras.layers.MaxPooling3D(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.GlobalAveragePooling3D(),
    tf.keras.layers.Dense(len(CFG.classes), activation="softmax")
])
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
    optimizer=tf.keras.optimizers.Adam(0.001),
    metrics=[
        "accuracy"
    ]
)
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d_6 (Conv3D)                    │ (None, 10, 50, 100, 32)     │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_6 (MaxPooling3D)       │ (None, 5, 25, 50, 32)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_7 (Conv3D)                    │ (None, 5, 25, 50, 64)       │          55,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_7 (MaxPooling3D)       │ (None, 2, 12, 25, 64)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_8 (Conv3D)                    │ (None, 2, 12, 25, 128)      │         221,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_8 (MaxPooling3D)       │ (None, 1, 6, 12, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 1, 6, 12, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling3d_2           │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling3D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 280,586 (1.07 MB)
#  Trainable params: 280,586 (1.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "model_PreMouth_Resize.keras", 
    monitor="val_accuracy",
    mode="max",
    save_best_only=True
)
history = model.fit(
    train_ds,
    epochs=30, 
    validation_data=valid_ds, 
    callbacks=[checkpoint]
)
model.load_weights("model_PreMouth_Resize.keras")
# Out:
# Epoch 1/30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 143s 586ms/step - accuracy: 0.1232 - loss: 4.7459 - val_accuracy: 0.2779 - val_loss: 1.9590
# Epoch 2/30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 144s 598ms/step - accuracy: 0.3658 - loss: 1.7806 - val_accuracy: 0.4878 - val_loss: 1.4990
# Epoch 3/30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 143s 592ms/step - accuracy: 0.5205 - loss: 1.4255 - val_accuracy: 0.5728 - val_loss: 1.2800
# Epoch 4/30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 143s 595ms/step - accuracy: 0
30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 141s 585ms/step - accuracy: 0.8544 - loss: 0.3999 - val_accuracy: 0.6558 - val_loss: 1.5484
# Epoch 28/30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 141s 586ms/step - accuracy: 0.8452 - loss: 0.4308 - val_accuracy: 0.6776 - val_loss: 1.3690
# Epoch 29/30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 141s 584ms/step - accuracy: 0.8555 - loss: 0.4095 - val_accuracy: 0.6630 - val_loss: 1.4643
# Epoch 30/30
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 140s 583ms/step - accuracy: 0.8604 - loss: 0.4169 - val_accuracy: 0.6755 - val_loss: 1.4064

# %%
for metrics in [("loss", "val_loss"), ("accuracy", "val_accuracy")]:
    pd.DataFrame(history.history, columns=metrics).plot()
    plt.show()

# %%
# Guardar el modelo
model.save('LRW_Conv3D_resize.keras')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, LSTM, Dense, TimeDistributed, Dropout, Input

num_frames = 12  # Máximo número de frames por video
height = 50
width = 100
channels = 3
num_classes = 10

model = Sequential()

# Definir la forma de entrada utilizando Input
model.add(Input(shape=(num_frames, height, width, channels)))

# CNN para extraer características de cada frame
model.add(TimeDistributed(Conv2D(32, (3, 3), activation='relu', padding='same')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Conv2D(64, (3, 3), activation='relu', padding='same')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Flatten()))

# LSTM para capturar la secuencia temporal de las características extraídas
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.5))

# Capa final densa para la clasificación
model.add(Dense(num_classes, activation='softmax'))

# Compilar el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_20                  │ (None, 12, 50, 100, 32)     │             896 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_21                  │ (None, 12, 25, 50, 32)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_22                  │ (None, 12, 25, 50, 64)      │          18,496 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_23                  │ (None, 12, 12, 25, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_24                  │ (None, 12, 19200)           │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_8 (LSTM)                        │ (None, 128)                 │       9,896,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,917,130 (37.83 MB)
#  Trainable params: 9,917,130 (37.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_train = to_categorical(train_targets, num_classes=10)
y_valid = to_categorical(val_targets, num_classes=10)

# %%
train_ds_2 = tf.data.Dataset.from_tensor_slices((train_features, y_train)).shuffle(CFG.batch_size * 4).batch(CFG.batch_size).cache().prefetch(tf.data.AUTOTUNE)
valid_ds_2 = tf.data.Dataset.from_tensor_slices((val_features, y_valid)).batch(CFG.batch_size).cache().prefetch(tf.data.AUTOTUNE)

# %%
# Definir callbacks
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "LSTM_best_model.keras", 
    monitor="val_accuracy", 
    save_best_only=True, 
    mode="max"
)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    restore_best_weights=True
)

# Entrenar el modelo
history = model.fit(
    train_ds_2,
    epochs=10,
    batch_size=32,
    validation_data=valid_ds_2,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/10
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 380s 2s/step - accuracy: 0.0926 - loss: 2.5323 - val_accuracy: 0.1140 - val_loss: 2.3022
# Epoch 2/10
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 325s 1s/step - accuracy: 0.0975 - loss: 2.4089 - val_accuracy: 0.0933 - val_loss: 2.3030
# Epoch 3/10
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 311s 1s/step - accuracy: 0.1053 - loss: 2.3698 - val_accuracy: 0.0933 - val_loss: 2.3041
# Epoch 4/10
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - accuracy: 0.1044 - loss: 2.3356 - val_accuracy: 0.0933 - val_loss: 2.3035
# Epoch 5/10
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 311s 1s/step - accuracy: 0.1006 - loss: 2.3283 - val_accuracy: 0.0933 - val_loss: 2.3026
# Epoch 6/10
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 311s 1s/step - accuracy: 0.0960 - loss: 2.3240 - val_accuracy: 0.0933 - val_loss: 2.3034
